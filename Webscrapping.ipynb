# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
import requests as re

# %%
url="https://www.digit.in/top-products/best-smartwatches-in-india-182.html"

# %%
respons=re.get(url)

# %%
respons
# Out:
# <Response [200]>

# %%
text=BeautifulSoup(respons.text)

# %%
text
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://www.digit.in/images/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://www.digit.in/css/top10_v3.css?v=766" rel="stylesheet" type="text/css"/>
# <link href="https://static.digit.in/" rel="dns-prefetch"/>
# <link href="https://connect.facebook.net/" rel="dns-prefetch"/>
# <link href="https://securepubads.g.doubleclick.net/tag/js/gpt.js" rel="preconnect"/>
# <link as="font" crossorigin="" href="https://static.digit.in/barlow400.woff2" rel="preload"/>
# <link as="font" crossorigin="" href="https://static.digit.in/barlow600.woff2" rel="preload"/>
# <style type="text/css">
# ...

# %%
watch=text.select("h3")

# %%
watch
# Out:
# [<h3>Apple Watch Series 7</h3>,
#  <h3>Samsung Galaxy Watch4</h3>,
#  <h3>Garmin Fenix 7X Solar</h3>,
#  <h3>Fitbit Sense</h3>,
#  <h3>Mobvoi Ticwatch E3</h3>,
#  <h3>Apple Watch SE</h3>,
#  <h3>Fossil Gen 6</h3>,
#  <h3>Amazfit T-Rex Pro</h3>,
#  <h3>OPPO Watch</h3>,
#  <h3>Suunto 7</h3>]

# %%
os=text.select(".full_width+ li .value")

# %%
os
# Out:
# [<div class="value">Android</div>,
#  <div class="value">Android</div>,
#  <div class="value">NA</div>,
#  <div class="value">YES</div>,
#  <div class="value">NA</div>,
#  <div class="value">NA</div>,
#  <div class="value">NA</div>,
#  <div class="value">iOS, Android</div>,
#  <div class="value">Android</div>,
#  <div class="value">Google, Wear os by</div>]

# %%
proff=text.select(".full_width~ li+ li .value")

# %%
proff
# Out:
# [<div class="value">Yes</div>,
#  <div class="value">Yes</div>,
#  <div class="value">NA</div>,
#  <div class="value">YES</div>,
#  <div class="value">Yes</div>,
#  <div class="value">YES</div>,
#  <div class="value">Yes</div>,
#  <div class="value">Yes</div>,
#  <div class="value">Yes</div>,
#  <div class="value">Yes</div>]

# %%
watch_spec=pd.DataFrame({'Whatch_name':watch,'Watch_os':os,'Watch_proff':proff})

# %%
watch_spec
# Out:
#                Whatch_name              Watch_os Watch_proff
# 0   [Apple Watch Series 7]             [Android]       [Yes]
# 1  [Samsung Galaxy Watch4]             [Android]       [Yes]
# 2  [Garmin Fenix 7X Solar]                  [NA]        [NA]
# 3           [Fitbit Sense]                 [YES]       [YES]
# 4     [Mobvoi Ticwatch E3]                  [NA]       [Yes]
# 5         [Apple Watch SE]                  [NA]       [YES]
# 6           [Fossil Gen 6]                  [NA]       [Yes]
# 7      [Amazfit T-Rex Pro]        [iOS, Android]       [Yes]
# 8             [OPPO Watch]             [Android]       [Yes]
# 9               [Suunto 7]  [Google, Wear os by]       [Yes]

# %%
watch_spec.to_csv('C:/Users/Dinesh Kumar/OneDrive/Desktop/watch.csv')
